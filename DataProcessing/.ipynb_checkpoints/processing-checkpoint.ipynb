# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# load data

clt = pd.read_csv('CLT.csv', sep = ',')
cqt = pd.read_csv('CQT.csv', sep = ',')
ind = pd.read_csv('IND.csv', sep = ',')
jax = pd.read_csv('JAX.csv', sep = ',')
mdw = pd.read_csv('MDW.csv', sep = ',')
phl = pd.read_csv('PHL.csv', sep = ',')
phx = pd.read_csv('PHX.csv', sep = ',')

# %%
# aggregate dataset on month, year basis

# first, create month_num and year columns for each dataframe
clt['month_num'] = clt['date'].str.slice(5, 6)
clt['year'] = clt['date'].str.slice(0, 4)

cqt['month_num'] = clt['date'].str.slice(5, 6)
cqt['year'] = clt['date'].str.slice(0, 4)

ind['month_num'] = clt['date'].str.slice(5, 6)
ind['year'] = clt['date'].str.slice(0, 4)

jax['month_num'] = clt['date'].str.slice(5, 6)
jax['year'] = clt['date'].str.slice(0, 4)

mdw['month_num'] = clt['date'].str.slice(5, 6)
mdw['year'] = clt['date'].str.slice(0, 4)

phl['month_num'] = clt['date'].str.slice(5, 6)
phl['year'] = clt['date'].str.slice(0, 4)

phx['month_num'] = clt['date'].str.slice(5, 6)
phx['year'] = clt['date'].str.slice(0, 4)

# %%
# remove record_year columns before aggregation
clt.drop(columns=['record_max_temp_year', 'record_min_temp_year', 'date'])

cqt.drop(columns=['record_max_temp_year', 'record_min_temp_year', 'date'])

ind.drop(columns=['record_max_temp_year', 'record_min_temp_year', 'date'])

jax.drop(columns=['record_max_temp_year', 'record_min_temp_year', 'date'])

mdw.drop(columns=['record_max_temp_year', 'record_min_temp_year', 'date'])

phl.drop(columns=['record_max_temp_year', 'record_min_temp_year', 'date'])

phx.drop(columns=['record_max_temp_year', 'record_min_temp_year', 'date'])

# remove date column before aggregation
clt.drop(columns=['date'])
cqt.drop(columns=['date'])
ind.drop(columns=['date'])
jax.drop(columns=['date'])
mdw.drop(columns=['date'])
phl.drop(columns=['date'])
phx.drop(columns=['date'])
# Out:
#      actual_mean_temp  actual_min_temp  actual_max_temp  average_min_temp  \
# 0                  98               86              109                82
# 1                  98               86              109                82
# 2                  94               79              108                82
# 3                  90               81               98                83
# 4                  94               84              103                83
# ..                ...              ...              ...               ...
# 360                98               89              107                81
# 361                99               90              108                81
# 362                99               87              110                81
# 363                98               86              110                81
# 364                96               85              107                82
#
#      average_max_temp  record_min_temp  record_max_temp  actual_precipitation  \
# ...

# %%
# aggregate each df based on year, month_num
clt.groupby(['year', 'month_num']).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# ...

# %%
# add city & state information to each csv

# CLT -> Charlotte, North Carolina
# CQT -> Los Angeles, California
# IND -> Indianapolis, Indiana
# JAX -> Jacksonville, Florida
# MDW -> Chicago, Illinois
# PHL -> Philadelphia, Pennsylvania
# PHX -> Phoenix, Arizona

clt['city'] = 'Charlotte'
clt['state'] = 'North Carolina'
clt['shortcode'] = 'CLT'

cqt['city'] = 'Los Angeles'
cqt['state'] = 'California'
cqt['shortcode'] = 'CQT'

ind['city'] = 'Indianapolis'
ind['state'] = 'Indiana'
ind['shortcode'] = 'IND'

jax['city'] = 'Jacksonville'
jax['state'] = 'Florida'
jax['shortcode'] = 'JAX'

mdw['city'] = 'Chicago'
mdw['state'] = 'Illinois'
mdw['shortcode'] = 'MDW'

phl['city'] = 'Philadelphia'
phl['state'] = 'Pennsylvania'
phl['shortcode'] = 'PHL'

phx['city'] = 'Phoenix'
phx['state'] = 'Arizona'
phx['shortcode'] = 'PHX'

# %%
# vertically join all of the dataframes together
final = pd.concat([clt, cqt, ind, jax, mdw, phl, phx])

# %%
# export df to csv
final.to_csv('final.csv', index=False)
